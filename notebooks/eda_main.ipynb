# %% [markdown]
# # Insider ML Engineer Challenge - Titanic Dataset

# %% [markdown]
# In this challenge, we are going to develop a full API to use it with AI.
#
# The Titanic Dataset can be found at [Kaggle](https://www.kaggle.com/competitions/titanic/data), but in this case, it is already downloaded in the [`dataset directory`](../dataset), due to its small size.

# %% [markdown]
# ## Requirements
#
# - Python 3.12

# %% [markdown]
# ### Preparing the environment
#
# **PS: The following commands may be used on a Linux terminal.**
#
# First, we need to create and activate our virtual environment (venv):
#
# ```bash
# python3 -m venv venv && source venv/bin/activate
# ```
#
# Then, using pip, we must download the dependecies from [`requirements.txt`](../requirements.txt)
#
# ```bash
# pip install -r requirements.txt
# ```
#
# ### Git LFS
#
# It is also good to install the Git LFS for uploading models to GitHub.
# In Linux systems, especifically Debian based like Ubuntu, we can do this in the terminal running:
#
# ```bash
# sudo apt install git-lfs
# ```
#
# Then, we must initialize Git LFS in our project directory:
#
# ```bash
# git lfs install
# ```
#
# Now, we need to make it track our pickle files (in this case, there is just one file):
#
# ```bash
# git lfs track "*.pkl"
# ```
#
# This will create (or update) our [`.gitattributes`](../.gitattributes) file, which will not store the content in the Git repository, but link it into GitHub. In this way, we will not upload these bigger files, but just a link to it.
#
# In this challenge, our models will be quite small, but we still will be using Git LFS because of real-world good practices.

# %% [markdown]
# ## Code
#
# **This code will focus on discovering the useful data for training the models. Therefore, _it is not_ the clean EDA and feature engineering Pipeline used in the API. Normally, we would put in .gitignore, but for docs reasons we will keep it.**

# %% [markdown]
# One way to start is by knowing that the [`gender_submission file`](../dataset/gender_submission.csv) assumes that all women survived and all men died. This is based on the priority of women and children first in accident cases. With this file, we get a **0.76555** score in Kaggle, we can use this value to estimate a minimum threshold for our AI to exceed.
#
# Let's start importing our dependencies and then checking if the gender is a good parameter.

# %% [markdown]
# ### Importing Dependecies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVC

# %matplotlib inline

# %% [markdown]
# ### Load dataset

# %%
train_df = pd.read_csv("../dataset/train.csv")

# %%
test_df = pd.read_csv("../dataset/test.csv")

# %% [markdown]
# ### Feature Engineering

# %%
train_df["number_of_cabins"] = train_df.Cabin.apply(
    lambda x: 0 if pd.isna(x) else len(x.split(" "))
)

# %%
train_df["cabin_categories"] = train_df.Cabin.apply(lambda x: str(x)[0])

# %%
# Extract title from Name
train_df["name_title"] = train_df["Name"].apply(
    lambda x: x.split(",")[1].split(".")[0].strip()
)

# %%
train_df["train_test_join"] = 1
test_df["train_test_join"] = 0

test_df["Survived"] = -1  # Creating column Survived in test split

# %%
train_test_df = pd.concat(
    [train_df, test_df]
)  # We will group them for general analysis

# %%
train_test_df["Embarked"] = train_test_df["Embarked"].fillna("C")

# %%
# Fill null with the median age and fare
train_test_df.Age = train_test_df.Age.fillna(train_test_df.Age.median())
train_test_df.Fare = train_test_df.Fare.fillna(train_test_df.Fare.median())

# Normalizing Fare
train_test_df["norm_fare"] = np.log(train_test_df.Fare + 1)

# %%
# Count how many cabins a person has (0 if missing, otherwise count how many space-separated entries)
train_test_df["cabin_multiple"] = train_test_df.Cabin.apply(
    lambda x: 0 if pd.isna(x) else len(x.split(" "))
)

# Take the first letter of the cabin string (e.g., 'C85' → 'C'; NaN becomes 'n')
train_test_df["cabin_categories"] = train_test_df.Cabin.apply(
    lambda x: str(x)[0]
)

train_test_df.drop(columns=["Ticket"], inplace=True, errors='ignore') # If Ticket does is already dropped, ignores error

# Extract the title from the name (e.g., "Mr", "Mrs", "Miss", etc.)
train_test_df["name_title"] = train_test_df.Name.apply(
    lambda x: x.split(",")[1].split(".")[0].strip()
)

# %%
# Converting
train_test_df["cabin_multiple"] = train_test_df["cabin_multiple"].astype(str)
train_test_df.Pclass = train_test_df.Pclass.astype(str)

# Define categorical and numeric features
categorical_cols = [
    "Pclass",
    "Sex",
    "Embarked",
    "cabin_categories",
    "cabin_multiple",
    "name_title",
]
numerical_cols = [
    "Age",
    "SibSp",
    "Parch",
    "norm_fare",
]
meta_col = ["train_test_join"]  # used to split train/test later

# Apply one-hot encoding only to categorical columns
# We already done it to good categories for analysis purposes, but we did not merged them with our train before. This time, we are going to one hot encode all of them.
categorical_dummies = pd.get_dummies(train_test_df[categorical_cols])

# Combine with numerical + meta columns
train_test_dummies = pd.concat(
    [
        train_test_df[numerical_cols + meta_col].reset_index(drop=True),
        categorical_dummies.reset_index(drop=True),
    ],
    axis=1,
)

# %%
# Split train and test
X_full_train = train_test_dummies[train_test_dummies.train_test_join == 1].drop(
    ["train_test_join"], axis=1
)
X_test = train_test_dummies[train_test_dummies.train_test_join == 0].drop(
    ["train_test_join"], axis=1
)
y_full_train = train_test_df[train_test_df.train_test_join == 1].Survived

# Split training and validation
X_train, X_val, y_train, y_val = train_test_split(
    X_full_train,
    y_full_train,
    test_size=0.2,
    random_state=29,
    stratify=y_full_train,
)

# Scale data
scale = StandardScaler()

# Columns to scale
columns_to_scale = ["Age", "SibSp", "Parch", "norm_fare"]

# Fit scaler only on X_train, then transform all
X_train[columns_to_scale] = scale.fit_transform(X_train[columns_to_scale])
X_val[columns_to_scale] = scale.transform(X_val[columns_to_scale])
X_test[columns_to_scale] = scale.transform(X_test[columns_to_scale])

# %% [markdown]
# ### Model

# %% [markdown]
# The RandomForest and SVC models were chosen based on previous personal works with this dataset

# %%
rf_model = RandomForestClassifier(random_state=29)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_val)

# Evaluation
print("Random Forest Evaluation:")
print("Accuracy:", accuracy_score(y_val, y_pred_rf))
print("F1 Score:", f1_score(y_val, y_pred_rf))
print("Precision:", precision_score(y_val, y_pred_rf))
print("Recall:", recall_score(y_val, y_pred_rf))
# Out:
# Random Forest Evaluation:
# Accuracy: 0.8435754189944135
# F1 Score: 0.8
# Precision: 0.7887323943661971
# Recall: 0.8115942028985508

# %%
svm_model = SVC(probability = True, random_state=29)
svm_model.fit(X_train, y_train)
y_pred_svm = svm_model.predict(X_val)

# Evaluation
print("SVC Evaluation:")
print("Accuracy:", accuracy_score(y_val, y_pred_svm))
print("F1 Score:", f1_score(y_val, y_pred_svm))
print("Precision:", precision_score(y_val, y_pred_svm))
print("Recall:", recall_score(y_val, y_pred_svm))
# Out:
# SVC Evaluation:
# Accuracy: 0.8491620111731844
# F1 Score: 0.8
# Precision: 0.8181818181818182
# Recall: 0.782608695652174

# %% [markdown]
# ### Fine-tuning

# %%
def clf_performance(model, name):
    print(f"\nBest {name} Model Evaluation:")
    print("Best parameters:", model.best_params_)

    y_pred = model.predict(X_val)
    print("Accuracy:", accuracy_score(y_val, y_pred))
    print("F1 Score:", f1_score(y_val, y_pred))
    print("Precision:", precision_score(y_val, y_pred))
    print("Recall:", recall_score(y_val, y_pred))
    print("Classification Report:\n", classification_report(y_val, y_pred))

# %%
rf = RandomForestClassifier(random_state=29)
param_grid_rf = {
    "n_estimators": [100, 200, 400, 500],
    "criterion": ["gini", "entropy"],
    "bootstrap": [True],
    "max_depth": [15, 20, 25],
    "max_features": ["log2", "sqrt", 10],
    "min_samples_leaf": [2, 3],
    "min_samples_split": [2, 3],
}

clf_rf = GridSearchCV(rf, param_grid=param_grid_rf, cv=5, verbose=2, n_jobs=-1)
best_clf_rf = clf_rf.fit(X_train, y_train)
clf_performance(best_clf_rf, "Random Forest")
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=  -0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=  -0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=  -0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=  -0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=  -0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=  -0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=  -0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=  -0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=15, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# ...
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.3s[CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.3s
#
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   1.0s
#
# Best Random Forest Model Evaluation:
# Best parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy: 0.8715083798882681
# F1 Score: 0.8244274809160306
# Precision: 0.8709677419354839
# Recall: 0.782608695652174
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       110
#            1       0.87      0.78      0.82        69
#
#     accuracy                           0.87       179
#    macro avg       0.87      0.85      0.86       179
# weighted avg       0.87      0.87      0.87       179

# %%
# SVC
svc = SVC(probability=True, random_state=29)
param_grid_svc = [
    {
        "kernel": ["rbf"],
        "gamma": [0.1, 0.5, 1, 2, 5, 10],
        "C": [0.1, 1, 10, 100, 1000],
    },
    {"kernel": ["linear"], "C": [0.1, 1, 10, 100, 1000]},
    {"kernel": ["poly"], "degree": [2, 3, 4, 5], "C": [0.1, 1, 10, 100, 1000]},
]

clf_svc = GridSearchCV(
    svc, param_grid=param_grid_svc, cv=5, verbose=2, n_jobs=-1
)
best_clf_svc = clf_svc.fit(X_train, y_train)
clf_performance(best_clf_svc, "SVC")
# Out:
# Fitting 5 folds for each of 55 candidates, totalling 275 fits
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=0.1, gamma=0.5, kernel=rbf; total time=   0.2s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=0.1, gamma=0.5, kernel=rbf; total time=   0.2s
# [CV] END .......................C=0.1, gamma=0.5, kernel=rbf; total time=   0.3s
# [CV] END .......................C=0.1, gamma=0.5, kernel=rbf; total time=   0.2s
# [CV] END .......................C=0.1, gamma=0.5, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=2, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=2, kernel=rbf; total time=   0.1s
# [CV] END .........................C=0.1, gamma=2, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=2, kernel=rbf; total time=   0.1s
# [CV] END .........................C=0.1, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=2, kernel=rbf; total time=   0.2s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.2s[CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.2s
#
# [CV] END .........................C=0.1, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=1, gamma=0.5, kernel=rbf; total time=   0.1s
# [CV] END .........................C=1, gamma=0.5, kernel=rbf; total time=   0.2s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.1s[CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.3s
#
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.2s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.2s
# [CV] END .........................C=1, gamma=0.5, kernel=rbf; total time=   0.1s
# [CV] END .........................C=1, gamma=0.5, kernel=rbf; total time=   0.1s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=1, gamma=0.5, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=2, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=2, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=2, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=2, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=2, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=1, gamma=10, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=1, gamma=10, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=1, gamma=10, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.5, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=1, gamma=10, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.5, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=1, gamma=10, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.3s
# [CV] END ........................C=10, gamma=0.5, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.5, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.5, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=10, gamma=2, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.3s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.3s
# [CV] END ..........................C=10, gamma=2, kernel=rbf; total time=   0.3s
# [CV] END ..........................C=10, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=10, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.3s
# [CV] END ..........................C=10, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=10, gamma=2, kernel=rbf; total time=   0.3s
# [CV] END ..........................C=10, gamma=2, kernel=rbf; total time=   0.3s
# [CV] END ..........................C=10, gamma=5, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=10, gamma=2, kernel=rbf; total time=   0.3s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.3s
# [CV] END ..........................C=10, gamma=5, kernel=rbf; total time=   0.3s
# [CV] END .........................C=10, gamma=10, kernel=rbf; total time=   0.3s
# [CV] END .........................C=10, gamma=10, kernel=rbf; total time=   0.2s
# [CV] END .........................C=10, gamma=10, kernel=rbf; total time=   0.3s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END .........................C=10, gamma=10, kernel=rbf; total time=   0.3s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END .......................C=100, gamma=0.5, kernel=rbf; total time=   0.4s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=10, gamma=10, kernel=rbf; total time=   0.4s
# [CV] END .......................C=100, gamma=0.5, kernel=rbf; total time=   0.6s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END .......................C=100, gamma=0.5, kernel=rbf; total time=   0.5s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.8s
# [CV] END .......................C=100, gamma=0.5, kernel=rbf; total time=   0.4s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END .........................C=100, gamma=5, kernel=rbf; total time=   0.3s
# [CV] END .........................C=100, gamma=2, kernel=rbf; total time=   0.6s
# [CV] END .........................C=100, gamma=5, kernel=rbf; total time=   0.3s
# [CV] END .........................C=100, gamma=2, kernel=rbf; total time=   0.6s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END .........................C=100, gamma=2, kernel=rbf; total time=   0.4s
# [CV] END .........................C=100, gamma=5, kernel=rbf; total time=   0.3s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END .........................C=100, gamma=5, kernel=rbf; total time=   0.3s
# [CV] END .......................C=100, gamma=0.5, kernel=rbf; total time=   0.8s
# [CV] END ........................C=100, gamma=10, kernel=rbf; total time=   0.2s
# [CV] END .........................C=100, gamma=2, kernel=rbf; total time=   0.4s
# [CV] END ........................C=100, gamma=10, kernel=rbf; total time=   0.2s
# [CV] END .........................C=100, gamma=5, kernel=rbf; total time=   0.3s
# [CV] END .........................C=100, gamma=2, kernel=rbf; total time=   0.5s
# [CV] END ........................C=100, gamma=10, kernel=rbf; total time=   0.2s
# [CV] END ........................C=100, gamma=10, kernel=rbf; total time=   0.2s
# [CV] END ........................C=100, gamma=10, kernel=rbf; total time=   0.3s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   0.8s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   1.0s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END ......................C=1000, gamma=0.5, kernel=rbf; total time=   1.4s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   1.3s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   1.2s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   1.0s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   0.8s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   1.0s
# [CV] END ......................C=1000, gamma=0.5, kernel=rbf; total time=   1.8s
# [CV] END ........................C=1000, gamma=2, kernel=rbf; total time=   0.7s
# [CV] END ........................C=1000, gamma=5, kernel=rbf; total time=   0.5s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   1.0s
# [CV] END ........................C=1000, gamma=2, kernel=rbf; total time=   0.8s
# [CV] END ........................C=1000, gamma=5, kernel=rbf; total time=   0.3s
# [CV] END ........................C=1000, gamma=2, kernel=rbf; total time=   1.0s
# [CV] END ........................C=1000, gamma=5, kernel=rbf; total time=   0.4s
# [CV] END ........................C=1000, gamma=5, kernel=rbf; total time=   0.6s
# [CV] END ......................C=1000, gamma=0.5, kernel=rbf; total time=   1.7s
# [CV] END .......................C=1000, gamma=10, kernel=rbf; total time=   0.3s
# [CV] END ........................C=1000, gamma=5, kernel=rbf; total time=  -1.4s
# [CV] END ........................C=1000, gamma=2, kernel=rbf; total time=  -1.3s
# [CV] END ........................C=1000, gamma=2, kernel=rbf; total time=  -1.3s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.1s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.1s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.1s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.1s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.1s
# [CV] END .......................C=1000, gamma=10, kernel=rbf; total time=  -1.7s
# [CV] END .......................C=1000, gamma=10, kernel=rbf; total time=  -1.7s
# [CV] END .................................C=1, kernel=linear; total time=   0.1s
# [CV] END .................................C=1, kernel=linear; total time=   0.1s
# [CV] END .................................C=1, kernel=linear; total time=   0.1s
# [CV] END .................................C=1, kernel=linear; total time=   0.1s
# [CV] END ......................C=1000, gamma=0.5, kernel=rbf; total time=   0.3s
# [CV] END .................................C=1, kernel=linear; total time=   0.1s
# [CV] END .......................C=1000, gamma=10, kernel=rbf; total time=  -1.5s
# [CV] END ................................C=10, kernel=linear; total time=   0.3s
# [CV] END ................................C=10, kernel=linear; total time=   0.3s
# [CV] END ................................C=10, kernel=linear; total time=   0.4s
# [CV] END ................................C=10, kernel=linear; total time=   0.5s
# [CV] END .......................C=1000, gamma=10, kernel=rbf; total time=   0.5s
# [CV] END ................................C=10, kernel=linear; total time=   0.6s
# [CV] END ......................C=1000, gamma=0.5, kernel=rbf; total time=   0.3s
# [CV] END ...............................C=100, kernel=linear; total time=   2.2s
# [CV] END ...............................C=100, kernel=linear; total time=   2.2s
# [CV] END ...............................C=100, kernel=linear; total time=   2.7s
# [CV] END .......................C=0.1, degree=2, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=2, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=2, kernel=poly; total time=   0.1s
# [CV] END ...............................C=100, kernel=linear; total time=   2.9s
# [CV] END .......................C=0.1, degree=2, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=2, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=3, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=3, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=3, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=3, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=3, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=4, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=4, kernel=poly; total time=   0.1s[CV] END .......................C=0.1, degree=4, kernel=poly; total time=   0.1s
#
# [CV] END .......................C=0.1, degree=4, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=4, kernel=poly; total time=   0.1s
# [CV] END ...............................C=100, kernel=linear; total time=   3.5s
# [CV] END .......................C=0.1, degree=5, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=5, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=5, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=5, kernel=poly; total time=   0.1s
# [CV] END .......................C=0.1, degree=5, kernel=poly; total time=   0.2s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.2s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.2s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.2s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=5, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=5, kernel=poly; total time=   0.1s
# [CV] END .........................C=1, degree=5, kernel=poly; total time=   0.2s
# [CV] END .........................C=1, degree=5, kernel=poly; total time=   0.2s
# [CV] END .........................C=1, degree=5, kernel=poly; total time=   0.1s
# [CV] END ........................C=10, degree=2, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=2, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=2, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=2, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=3, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=2, kernel=poly; total time=   0.3s
# [CV] END ........................C=10, degree=3, kernel=poly; total time=   0.1s
# [CV] END ........................C=10, degree=3, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=3, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=3, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=4, kernel=poly; total time=   0.1s
# [CV] END ........................C=10, degree=4, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=4, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=4, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=4, kernel=poly; total time=   0.3s
# [CV] END ........................C=10, degree=5, kernel=poly; total time=   0.1s
# [CV] END ........................C=10, degree=5, kernel=poly; total time=   0.3s
# [CV] END ........................C=10, degree=5, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=5, kernel=poly; total time=   0.2s
# [CV] END ........................C=10, degree=5, kernel=poly; total time=   0.2s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   0.5s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   0.6s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   1.0s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   0.7s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   0.3s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   0.8s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   0.5s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   0.3s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   0.5s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   0.5s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   0.4s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   0.3s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   0.3s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   0.3s
# [CV] END .......................C=100, degree=5, kernel=poly; total time=   0.2s
# [CV] END .......................C=100, degree=5, kernel=poly; total time=   0.3s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   0.4s
# [CV] END .......................C=100, degree=5, kernel=poly; total time=   0.3s
# [CV] END .......................C=100, degree=5, kernel=poly; total time=   0.3s
# [CV] END .......................C=100, degree=5, kernel=poly; total time=   0.4s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=   2.1s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=   5.5s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=   6.0s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=   4.0s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=   1.0s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=   1.6s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=   1.4s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=   1.5s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=   1.1s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=   1.8s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=   1.0s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=   6.2s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=   2.2s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=   1.3s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=   1.9s
# [CV] END ......................C=1000, degree=5, kernel=poly; total time=   1.8s
# [CV] END ......................C=1000, degree=5, kernel=poly; total time=   1.9s
# [CV] END ......................C=1000, degree=5, kernel=poly; total time=   1.7s
# [CV] END ......................C=1000, degree=5, kernel=poly; total time=   1.7s
# [CV] END ......................C=1000, degree=5, kernel=poly; total time=   2.7s
# [CV] END ..............................C=1000, kernel=linear; total time=  39.7s
# [CV] END ..............................C=1000, kernel=linear; total time=  44.1s
# [CV] END ..............................C=1000, kernel=linear; total time=  44.3s
# [CV] END ..............................C=1000, kernel=linear; total time=  46.8s
# [CV] END ..............................C=1000, kernel=linear; total time= 1.1min
#
# Best SVC Model Evaluation:
# Best parameters: {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# Accuracy: 0.8491620111731844
# F1 Score: 0.8
# Precision: 0.8181818181818182
# Recall: 0.782608695652174
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       110
#            1       0.82      0.78      0.80        69
#
#     accuracy                           0.85       179
#    macro avg       0.84      0.84      0.84       179
# weighted avg       0.85      0.85      0.85       179

# %% [markdown]
# Comparing both SVC and Random Forest, the result is that overall, the best approach is using the SVC method.
# There is a better way to make a good analysis using the collected metrics, but for this case where we are going to test it in Kaggle, we will use the model with best macro average.
# We could also create an Ensemble of the top SVC models, but for now, we will just use the best one of each type of model.

# %%
joblib.dump(best_clf_svc.best_estimator_, "../models/best_svc_model.pkl")
joblib.dump(best_clf_rf.best_estimator_, "../models/best_rf_model.pkl")
# Out:
# ['../models/best_rf_model.pkl']

# %%
model = joblib.load("../models/best_svc_model.pkl")

print(model.feature_names_in_)
# Out:
# ['Age' 'SibSp' 'Parch' 'norm_fare' 'Pclass_1' 'Pclass_2' 'Pclass_3'
#  'Sex_female' 'Sex_male' 'Embarked_C' 'Embarked_Q' 'Embarked_S'
#  'cabin_categories_A' 'cabin_categories_B' 'cabin_categories_C'
#  'cabin_categories_D' 'cabin_categories_E' 'cabin_categories_F'
#  'cabin_categories_G' 'cabin_categories_T' 'cabin_categories_n'
#  'cabin_multiple_0' 'cabin_multiple_1' 'cabin_multiple_2'
#  'cabin_multiple_3' 'cabin_multiple_4' 'name_title_Capt' 'name_title_Col'
#  'name_title_Don' 'name_title_Dona' 'name_title_Dr' 'name_title_Jonkheer'
#  'name_title_Lady' 'name_title_Major' 'name_title_Master'
#  'name_title_Miss' 'name_title_Mlle' 'name_title_Mme' 'name_title_Mr'
#  'name_title_Mrs' 'name_title_Ms' 'name_title_Rev' 'name_title_Sir'
#  'name_title_the Countess']
